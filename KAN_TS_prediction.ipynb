# %% [markdown]
# # KAN for Time Series Forecasting Demo
#
# ## 1. Import Packages

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from synthetic import simulate_var
from torch.utils.data import DataLoader, TensorDataset
from kan import KAN
from models.model_helper import activation_helper
from tqdm import tqdm

torch.set_default_dtype(torch.float64)

# %% [markdown]
# ## 2. Hyperparameters

# %%
lag = 2  # number of lags
T = 1001  # number of time points
num_series = 2  # number of time series

batch_size = 32
epochs = 20
lr = 1e-3

dim_input = num_series * lag
dim_output = 1

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## 3. Generate Data

# %%
# Simulate data with causal relationships
X_np, beta, GC = simulate_var(p=num_series, T=T, lag=lag, sparsity=0.9, beta_value=0.8, sd=0.1)
X = torch.tensor(X_np[np.newaxis], dtype=torch.float32)  # add one new dimension for X

# %%
# Plot data
fig, axarr = plt.subplots(1, 2, figsize=(10, 3))
axarr[0].plot(X_np)
axarr[0].set_xlabel('T')
axarr[0].set_title('Entire time series')
axarr[1].plot(X_np[:50])
axarr[1].set_xlabel('T')
axarr[1].set_title('First 50 time points')
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Plot the granger causality among time series

# %%
print(GC)

plt.imshow(GC, cmap='Blues')
plt.title('GC actual')
plt.ylabel('Affected series')
plt.xlabel('Causal series')
plt.xticks([])
plt.yticks([])
# plt.colorbar()
plt.show()
# Out:
# [[1 0]
#  [0 1]]

# %% [markdown]
# ## 4. Prepare the Data
#
# - In this section, we choose TS1 as the target time series.
#
# - The lags of the rest 4 series and TS1 itself will be used to predict the current value of TS1.
#
# - For TS1, it is affected by TS0, TS1, TS3.

# %%
target_series = 0  # the series we want to predict

# %%
def pd_data(X):
    '''
    Use dataframe to show the data structure
    Y: target series
    ts{}_lag{}: value of time series {} with lag {}
    '''
    Y = X[:, :, target_series]
    df = pd.DataFrame({'Y': Y[0,:].detach().numpy()})[lag:]
    for i in range(num_series):
        for j in range(lag):
            df['ts{}_lag{}'.format(i, lag-j)] = X[0, :, i].detach().numpy()[j:-lag+j]
    return df

def rearrange_data(X):
    '''
    Rearrange the time series, to form a data with lags

    Input:
        X: tensor with shape (1, num_series, T)
    Output:
        array: tensor with shape (num_series * lag, T-lag)
    '''
    li = []
    for i in range(num_series):
        for j in range(lag):
            li.append(X[0, :, i].detach().numpy()[j:-lag+j])

    # transfer li to tensor
    array = torch.tensor(li, dtype=torch.float32).T

    return array

# %%
array = rearrange_data(X)
print(array.shape)

Y = X[:, :, target_series][0, :T-lag].reshape(1, T-lag).T
print(Y.shape)

# Show the data structure using dataframe
# pd_data(X)

# change the data type from float to double
array = array.double()
Y = Y.double()
# Out:
# torch.Size([999, 4])
# torch.Size([999, 1])
# /var/folders/yl/m5cgc23j1gbfcvxxglrgsk0w0000gn/T/ipykernel_74962/3451235973.py:29: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_9d63z49rj_/croot/pytorch_1681837279022/work/torch/csrc/utils/tensor_new.cpp:233.)
#   array = torch.tensor(li, dtype=torch.float32).T

# %%
dataset = {}
dataset['train_input'] = array.to(device)
dataset['test_input'] = array.to(device)
dataset['train_label'] = Y.to(device)
dataset['test_label'] = Y.to(device)

# %% [markdown]
# ## 5. KAN demo for Prediction

# %%
model = KAN(width=[dim_input, 3, dim_output], grid=3, k=3, seed=42)
model(array)
model.plot()
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
results = model.fit(dataset, opt='LBFGS', steps=20, lamb=0.001);
model.plot()
# Out:
# | train_loss: 1.15e-02 | test_loss: 1.15e-02 | reg: 4.15e+00 | : 100%|█| 20/20 [00:04<00:00,  4.05it
# saving model version 0.1

# %%
output = model(dataset['test_input'])

# plot output
fig, axarr = plt.subplots(1, 2, figsize=(10, 3))
axarr[0].plot(dataset['test_label'].detach().numpy(), label='True')
axarr[0].plot(output.detach().numpy(), label='Predicted')
axarr[0].set_xlabel('T')
axarr[0].set_title('Entire time series')
axarr[0].legend()
axarr[1].plot(dataset['test_label'].detach().numpy()[:50], label='True')
axarr[1].plot(output.detach().numpy()[:50], label='Predicted')
axarr[1].set_xlabel('T')
axarr[1].set_title('First 50 time points')
axarr[1].legend()
plt.tight_layout()
plt.show()

# %%
# set the size of the figure
plt.figure(figsize=(10, 3))
plt.plot(results['train_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss for KAN')
plt.show()

# %%
model.acts_scale
# Out:
# [tensor([[0.1999, 0.0802, 0.1711, 0.0128],
#          [0.1101, 0.2969, 0.2902, 0.0067],
#          [0.4663, 0.0080, 0.0046, 0.0039]]),
#  tensor([[2.6937e-04, 8.4912e-05, 8.5312e-01]])]

# %%
model.node_scores[0]
# Out:
# tensor([0.9982, 0.0172, 0.0091, 0.0076], grad_fn=<MeanBackward1>)

# %%
model = model.prune()
model.plot()
# Out:
# saving model version 0.2

# %% [markdown]
# This result is exciting as it shows how each time series can affect the target series.
#
# Here TS1 will affect itself with lag=1, and this plot clearly shows this effect. Even though this demo setting is a quite simple and naive one, we can still hope that KAN can idealy work on this situation and by using pruning skill, it can find the granger causal relationships.

# %% [markdown]
# ## 6. Show the KAN output for predicting

# %%
output = model(dataset['test_input'])

# plot output
fig, axarr = plt.subplots(1, 2, figsize=(10, 3))
axarr[0].plot(dataset['test_label'].detach().numpy(), label='True')
axarr[0].plot(output.detach().numpy(), label='Predicted')
axarr[0].set_xlabel('T')
axarr[0].set_title('Entire time series')
axarr[0].legend()
axarr[1].plot(dataset['test_label'].detach().numpy()[:50], label='True')
axarr[1].plot(output.detach().numpy()[:50], label='Predicted')
axarr[1].set_xlabel('T')
axarr[1].set_title('First 50 time points')
axarr[1].legend()
plt.tight_layout()
plt.show()

# %%
results2 = model.fit(dataset, opt='LBFGS', steps=20, lamb=0.001);
model.plot()
# Out:
# | train_loss: 9.51e-03 | test_loss: 9.51e-03 | reg: 5.25e+00 | : 100%|█| 20/20 [00:02<00:00,  7.12it
# saving model version 0.3

# %%
# set the size of the figure
plt.figure(figsize=(10, 3))
plt.plot(results['train_loss'], label='Before Pruning')
plt.plot(results2['train_loss'], label='After Pruning')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale('log')
plt.title('Training Loss for KAN w/ and w/o Pruning')
plt.legend()
plt.show()

# %%
output = model(dataset['test_input'])

# plot output
fig, axarr = plt.subplots(1, 2, figsize=(10, 3))
axarr[0].plot(dataset['test_label'].detach().numpy(), label='True')
axarr[0].plot(output.detach().numpy(), label='Predicted')
axarr[0].set_xlabel('T')
axarr[0].set_title('Entire time series')
axarr[0].legend()
axarr[1].plot(dataset['test_label'].detach().numpy()[:50], label='True')
axarr[1].plot(output.detach().numpy()[:50], label='Predicted')
axarr[1].set_xlabel('T')
axarr[1].set_title('First 50 time points')
axarr[1].legend()
plt.tight_layout()
plt.show()

# %%
model.auto_symbolic()
# Out:
# fixing (0,0,0) with x, r2=0.9917493068942548, c=1
# fixing (0,1,0) with 0
# fixing (0,2,0) with 0
# fixing (0,3,0) with 0
# fixing (1,0,0) with cos, r2=0.9997650798981621, c=2
# saving model version 0.4

# %%
from kan import nsimplify, ex_round

sf = model.symbolic_formula()[0][0]
nsimplify(ex_round(ex_round(sf, 3),3))
# Out:
# 15/53 - 161*cos(1281*x_1/1000 + 153/125)/187
